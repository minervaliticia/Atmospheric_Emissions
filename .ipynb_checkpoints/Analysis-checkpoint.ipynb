# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import requests
from bs4 import BeautifulSoup
import re

# %%
data = pd.read_excel("atmoshpericemissionsghg.xlsx", header = [3], sheet_name = "GHG total ")
ghg_indus_grp = data.loc[:22]

# %%
ghg_indus_sec_grp = data.loc[26:158]

# %%
ghg_indus_grp.head()
# Out:
#   Unnamed: 0 Unnamed: 1                                         Unnamed: 2  \
# 0          A        NaN                  Agriculture, forestry and fishing
# 1          B        NaN                               Mining and quarrying
# 2          C        NaN                                      Manufacturing
# 3          D        NaN  Electricity, gas, steam and air conditioning s...
# 4          E        NaN  Water supply; sewerage, waste management and r...
#
#        1990      1991      1992      1993      1994      1995      1996  ...  \
# 0   55978.4   55808.5   55510.4   54725.4   55487.3   55391.7   56706.2  ...
# 1   50762.1   50877.2   51480.6   51092.0   44876.2   46739.8   46903.0  ...
# 2  176067.9  177032.4  170118.3  165079.3  168003.9  166085.4  167363.6  ...
# 3  217638.6  214348.2  202484.4  185006.1  180725.0  178167.0  177971.4  ...
# 4   75232.5   76756.7   76870.8   77189.4   77556.2   78634.3   79137.0  ...
#
# ...

# %%
ghg_indus_grp.rename(columns = {"Unnamed: 0": "Letter code", "Unnamed: 1": "None", "Unnamed: 2": "Industry"},\
                     inplace = True)
# Out:
# /var/folders/45/qc4989c57zlbtkmp2cnnpcfc0000gn/T/ipykernel_14537/4183557265.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ghg_indus_grp.rename(columns = {"Unnamed: 0": "Letter code", "Unnamed: 1": "None", "Unnamed: 2": "Industry"},\

# %%
ghg_indus_grp
# Out:
#    Letter code None                                           Industry  \
# 0            A  NaN                  Agriculture, forestry and fishing
# 1            B  NaN                               Mining and quarrying
# 2            C  NaN                                      Manufacturing
# 3            D  NaN  Electricity, gas, steam and air conditioning s...
# 4            E  NaN  Water supply; sewerage, waste management and r...
# 5            F  NaN                                       Construction
# 6            G  NaN  Wholesale and retail trade; repair of motor ve...
# 7            H  NaN                              Transport and storage
# 8            I  NaN                    Accommodation and food services
# 9            J  NaN                      Information and communication
# 10           K  NaN                 Financial and insurance activities
# 11           L  NaN                             Real estate activities
# ...

# %%
del ghg_indus_grp["None"]

# %%
ghg_indus_grp.shape
# Out:
# (23, 34)

# %%
ghg_indus_grp.columns
# Out:
# Index(['Letter code',    'Industry',          1990,          1991,
#                 1992,          1993,          1994,          1995,
#                 1996,          1997,          1998,          1999,
#                 2000,          2001,          2002,          2003,
#                 2004,          2005,          2006,          2007,
#                 2008,          2009,          2010,          2011,
#                 2012,          2013,          2014,          2015,
#                 2016,          2017,          2018,          2019,
#                 2020,          2021],
#       dtype='object')

# %%
ghg_indus_grp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 34 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Letter code  21 non-null     object
#  1   Industry     22 non-null     object
#  2   1990         22 non-null     object
#  3   1991         22 non-null     float64
#  4   1992         22 non-null     float64
#  5   1993         22 non-null     float64
#  6   1994         22 non-null     float64
#  7   1995         22 non-null     float64
#  8   1996         22 non-null     float64
#  9   1997         22 non-null     float64
#  10  1998         22 non-null     float64
#  11  1999         22 non-null     float64
#  12  2000         22 non-null     float64
#  13  2001         22 non-null     float64
#  14  2002         22 non-null     float64
#  15  2003         22 non-null     float64
#  16  2004         22 non-null     float64
#  17  2005         22 non-null     float64
# ...

# %%
ghg_indus_grp.drop(21, inplace = True)
# Out:
# /var/folders/45/qc4989c57zlbtkmp2cnnpcfc0000gn/T/ipykernel_14537/1619219843.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ghg_indus_grp.drop(21, inplace = True)

# %%
ghg_indus_grp.reset_index(inplace=True)

# %%
ghg_indus_grp
# Out:
#     index Letter code                                           Industry  \
# 0       0           A                  Agriculture, forestry and fishing
# 1       1           B                               Mining and quarrying
# 2       2           C                                      Manufacturing
# 3       3           D  Electricity, gas, steam and air conditioning s...
# 4       4           E  Water supply; sewerage, waste management and r...
# 5       5           F                                       Construction
# 6       6           G  Wholesale and retail trade; repair of motor ve...
# 7       7           H                              Transport and storage
# 8       8           I                    Accommodation and food services
# 9       9           J                      Information and communication
# 10     10           K                 Financial and insurance activities
# 11     11           L                             Real estate activities
# ...

# %%
ghg_indus_grp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 35 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   index        22 non-null     int64
#  1   Letter code  21 non-null     object
#  2   Industry     22 non-null     object
#  3   1990         22 non-null     object
#  4   1991         22 non-null     float64
#  5   1992         22 non-null     float64
#  6   1993         22 non-null     float64
#  7   1994         22 non-null     float64
#  8   1995         22 non-null     float64
#  9   1996         22 non-null     float64
#  10  1997         22 non-null     float64
#  11  1998         22 non-null     float64
#  12  1999         22 non-null     float64
#  13  2000         22 non-null     float64
#  14  2001         22 non-null     float64
#  15  2002         22 non-null     float64
#  16  2003         22 non-null     float64
#  17  2004         22 non-null     float64
# ...

# %%
del ghg_indus_grp["index"]

# %%
ghg_indus_grp
# Out:
#    Letter code                                           Industry      1990  \
# 0            A                  Agriculture, forestry and fishing   55978.4
# 1            B                               Mining and quarrying   50762.1
# 2            C                                      Manufacturing  176067.9
# 3            D  Electricity, gas, steam and air conditioning s...  217638.6
# 4            E  Water supply; sewerage, waste management and r...   75232.5
# 5            F                                       Construction    5786.8
# 6            G  Wholesale and retail trade; repair of motor ve...     12127
# 7            H                              Transport and storage   66667.4
# 8            I                    Accommodation and food services    3139.2
# 9            J                      Information and communication    1199.4
# 10           K                 Financial and insurance activities       345
# ...

# %%
ghg_indus_grp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 34 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Letter code  21 non-null     object
#  1   Industry     22 non-null     object
#  2   1990         22 non-null     object
#  3   1991         22 non-null     float64
#  4   1992         22 non-null     float64
#  5   1993         22 non-null     float64
#  6   1994         22 non-null     float64
#  7   1995         22 non-null     float64
#  8   1996         22 non-null     float64
#  9   1997         22 non-null     float64
#  10  1998         22 non-null     float64
#  11  1999         22 non-null     float64
#  12  2000         22 non-null     float64
#  13  2001         22 non-null     float64
#  14  2002         22 non-null     float64
#  15  2003         22 non-null     float64
#  16  2004         22 non-null     float64
#  17  2005         22 non-null     float64
# ...

# %%
# changing -  in letter code to U
ghg_indus_grp.loc[20,"Letter code"] = "U"
ghg_indus_grp.loc[21,"Letter code"] = ""

# %%
ghg_indus_grp.tail()
# Out:
#    Letter code                                           Industry      1990  \
# 17           R                 Arts, entertainment and recreation    1797.7
# 18           S                           Other service activities    1162.8
# 19           T  Activities of households as employers; undiffe...      76.3
# 20           U                               Consumer expenditure  143893.7
# 21                                 Total greenhouse gas emissions  842944.6
#
#         1991      1992      1993      1994      1995      1996      1997  ...  \
# 17    1885.4    1712.9    1793.5    1739.3    1737.8    1793.2    1629.0  ...
# 18    1251.9    1191.3    1249.9    1241.8    1272.8    1326.1    1216.1  ...
# 19      75.1      76.8      78.2      81.9      83.4      81.6      84.3  ...
# 20  152359.2  150676.4  155426.7  150210.3  144708.1  159770.4  153848.3  ...
# 21  852556.5  833417.1  815888.8  804929.0  800882.1  827193.7  811315.7  ...
#
# ...

# %%
# slice total from table
total = ghg_indus_grp.iloc[-1:, :]

# %%
total.reset_index(inplace = True)

# %%
del total["index"]

# %%
del total["Letter code"]

# %%
total.rename(columns = {"Industry": ""}, inplace = True)
# Out:
# /var/folders/45/qc4989c57zlbtkmp2cnnpcfc0000gn/T/ipykernel_14537/3132066398.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   total.rename(columns = {"Industry": ""}, inplace = True)

# %%
total
# Out:
#                                        1990      1991      1992      1993  \
# 0  Total greenhouse gas emissions  842944.6  852556.5  833417.1  815888.8
#
#        1994      1995      1996      1997      1998  ...      2012      2013  \
# 0  804929.0  800882.1  827193.7  811315.7  815920.6  ...  656182.9  642592.4
#
#        2014      2015      2016      2017      2018      2019      2020  \
# 0  610966.9  600621.2  578877.3  563160.3  564144.5  550583.8  488596.4
#
#        2021
# 0  502786.6
#
# [1 rows x 33 columns]

# %%
# dropping row 21
ghg_indus_grp.drop(21, inplace = True)
# Out:
# /var/folders/45/qc4989c57zlbtkmp2cnnpcfc0000gn/T/ipykernel_14537/4226152770.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ghg_indus_grp.drop(21, inplace = True)

# %%
ghg_indus_grp.tail()
# Out:
#    Letter code                                           Industry      1990  \
# 16           Q            Human health and social work activities    6151.5
# 17           R                 Arts, entertainment and recreation    1797.7
# 18           S                           Other service activities    1162.8
# 19           T  Activities of households as employers; undiffe...      76.3
# 20           U                               Consumer expenditure  143893.7
#
#         1991      1992      1993      1994      1995      1996      1997  ...  \
# 16    6471.1    6828.4    6509.5    6587.7    6497.4    7042.7    6241.4  ...
# 17    1885.4    1712.9    1793.5    1739.3    1737.8    1793.2    1629.0  ...
# 18    1251.9    1191.3    1249.9    1241.8    1272.8    1326.1    1216.1  ...
# 19      75.1      76.8      78.2      81.9      83.4      81.6      84.3  ...
# 20  152359.2  150676.4  155426.7  150210.3  144708.1  159770.4  153848.3  ...
#
# ...

# %%
ghg_indus_grp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 34 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Letter code  21 non-null     object
#  1   Industry     21 non-null     object
#  2   1990         21 non-null     object
#  3   1991         21 non-null     float64
#  4   1992         21 non-null     float64
#  5   1993         21 non-null     float64
#  6   1994         21 non-null     float64
#  7   1995         21 non-null     float64
#  8   1996         21 non-null     float64
#  9   1997         21 non-null     float64
#  10  1998         21 non-null     float64
#  11  1999         21 non-null     float64
#  12  2000         21 non-null     float64
#  13  2001         21 non-null     float64
#  14  2002         21 non-null     float64
#  15  2003         21 non-null     float64
#  16  2004         21 non-null     float64
#  17  2005         21 non-null     float64
# ...

# %% [markdown]
# # 2. Visualization

# %%
x = total[[]]
height = 
plt.bar(total)
plt.show()

# %%
X = total.columns[1:]

# %%
y = total.transpose()

# %%
y

# %%
total

# %%
# df.set_index(df.columns[0])
v = total.set_index("")

# %%
v

# %%
z = v.transpose()

# %%
z.rename(columns = {"": "Year","": "Total greenhouse gas emissions"}, inplace = True)

# %%
z.head()

# %%
# height = z[["Total greenhouse gas emissions"]]
# plt.bar(z, height)
# plt.show()
height = z.iloc[:, :-4]

# %%
z.columns

# %%
plt.scatter(total)

# %%
total

# %%
# df = df.columns.to_frame().T.append(df, ignore_index=True)
# df.columns = range(len(df.columns))
total = total.columns.to_frame().T.append(total, ignore_index=True)
total.columns = range(len(total.columns))
# Out:
# /var/folders/45/qc4989c57zlbtkmp2cnnpcfc0000gn/T/ipykernel_14537/3131324144.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   total = total.columns.to_frame().T.append(total, ignore_index=True)

# %%
total
# Out:
#                                0         1         2         3         4   \
# 0                                      1990      1991      1992      1993
# 1  Total greenhouse gas emissions  842944.6  852556.5  833417.1  815888.8
#
#          5         6         7         8         9   ...        23        24  \
# 0      1994      1995      1996      1997      1998  ...      2012      2013
# 1  804929.0  800882.1  827193.7  811315.7  815920.6  ...  656182.9  642592.4
#
#          25        26        27        28        29        30        31  \
# 0      2014      2015      2016      2017      2018      2019      2020
# 1  610966.9  600621.2  578877.3  563160.3  564144.5  550583.8  488596.4
#
#          32
# 0      2021
# 1  502786.6
#
# [2 rows x 33 columns]

# %%
total.iloc[0, 0] = "Year"

# %%
total
# Out:
#                                0         1         2         3         4   \
# 0                            Year      1990      1991      1992      1993
# 1  Total greenhouse gas emissions  842944.6  852556.5  833417.1  815888.8
#
#          5         6         7         8         9   ...        23        24  \
# 0      1994      1995      1996      1997      1998  ...      2012      2013
# 1  804929.0  800882.1  827193.7  811315.7  815920.6  ...  656182.9  642592.4
#
#          25        26        27        28        29        30        31  \
# 0      2014      2015      2016      2017      2018      2019      2020
# 1  610966.9  600621.2  578877.3  563160.3  564144.5  550583.8  488596.4
#
#          32
# 0      2021
# 1  502786.6
#
# [2 rows x 33 columns]

# %%
df = total.transpose()

# %%
df.head()
# Out:
#       0                               1
# 0  Year  Total greenhouse gas emissions
# 1  1990                        842944.6
# 2  1991                        852556.5
# 3  1992                        833417.1
# 4  1993                        815888.8

# %%
# set the first row as index
# df.set_index(df.iloc[0].values)
df.columns = df.iloc[0,:]

# %%
df.head()
# Out:
# 0  Year  Total greenhouse gas emissions
# 0  Year  Total greenhouse gas emissions
# 1  1990                        842944.6
# 2  1991                        852556.5
# 3  1992                        833417.1
# 4  1993                        815888.8

# %%
df.drop(0, inplace = True)

# %%
df.reset_index(inplace = True)

# %%
del df["index"]

# %%
df.head()
# Out:
# 0  Year Total greenhouse gas emissions
# 0  1990                       842944.6
# 1  1991                       852556.5
# 2  1992                       833417.1
# 3  1993                       815888.8
# 4  1994                       804929.0

# %%
heights = df["Total greenhouse gas emissions"].to_list()
year = df["Year"].to_list()

# %%
plt.bar(year, heights)
plt.title("Yearly GHG emissions")
plt.xlabel("Year")
plt.ylabel("Total GHG emissions")
plt.show()

# %%
plt.scatter(year, heights)
plt.show()

# %%
ghg_indus_grp.head()
# Out:
#   Letter code                                           Industry      1990  \
# 0           A                  Agriculture, forestry and fishing   55978.4
# 1           B                               Mining and quarrying   50762.1
# 2           C                                      Manufacturing  176067.9
# 3           D  Electricity, gas, steam and air conditioning s...  217638.6
# 4           E  Water supply; sewerage, waste management and r...   75232.5
#
#        1991      1992      1993      1994      1995      1996      1997  ...  \
# 0   55808.5   55510.4   54725.4   55487.3   55391.7   56706.2   56132.4  ...
# 1   50877.2   51480.6   51092.0   44876.2   46739.8   46903.0   46035.6  ...
# 2  177032.4  170118.3  165079.3  168003.9  166085.4  167363.6  166017.9  ...
# 3  214348.2  202484.4  185006.1  180725.0  178167.0  177971.4  164572.8  ...
# 4   76756.7   76870.8   77189.4   77556.2   78634.3   79137.0   77930.1  ...
#
# ...

# %%
for i in ghg_indus_grp["Industry"]:
    ghg_indus_grp[i, "Total Emissions"]

# %%
# df['e'] = df.sum(axis=1, numeric_only=True)
ghg_indus_grp["Total Emissions"] = ghg_indus_grp.sum(axis = 1, numeric_only=True)
# Out:
# /var/folders/45/qc4989c57zlbtkmp2cnnpcfc0000gn/T/ipykernel_14537/3115115103.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ghg_indus_grp["Total Emissions"] = ghg_indus_grp.sum(axis = 1, numeric_only=True)

# %%
ghg_indus_grp.iloc[:, 7:]
# Out:
#         1995      1996      1997      1998      1999      2000      2001  \
# 0    55391.7   56706.2   56132.4   55674.8   55680.5   53597.6   51258.6
# 1    46739.8   46903.0   46035.6   44644.9   40727.5   38553.5   38437.0
# 2   166085.4  167363.6  166017.9  158150.0  143983.1  139163.4  132869.4
# 3   178167.0  177971.4  164572.8  170829.8  163215.0  176015.8  186999.9
# 4    78634.3   79137.0   77930.1   78942.1   74187.8   71553.1   69723.5
# 5     6424.0    6677.6    6914.9    7130.9    7402.4    7589.5    7883.9
# 6    13152.4   13486.1   13410.2   13778.1   14343.3   14650.9   14581.8
# 7    73415.5   79112.2   88152.6   93145.3   91479.0   94152.5   98015.3
# 8     3560.8    3742.7    3362.0    3542.4    3692.0    3762.4    3804.6
# 9     1376.2    1379.5    1314.1    1331.1    1379.7    1382.6    1320.9
# 10     364.9     368.4     327.3     328.3     340.1     338.8     336.7
# 11     780.9     812.9     760.8     807.3     861.4     883.9     881.9
# ...

# %%
# plt.xticks(range(len(bars_label)), bars_label, rotation='vertical')
x = ghg_indus_grp["Industry"].to_list()
y = ghg_indus_grp["Total Emissions"].to_list()

plt.bar(x, sorted(y))
plt.title("Total Emissions by Industries")
plt.xticks(x, rotation = "vertical")
plt.show()
